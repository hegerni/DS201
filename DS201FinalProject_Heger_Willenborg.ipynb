# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('laptop_data.csv')

# %%
df.drop_duplicates()
df['Ram'] = df['Ram'].str.extract('(\d+)').astype(int) #get rid of the GB associated with the RAM so it is easier to graph
df['Memory'] = df['Memory'].str.extract('(\d+)').astype(int) #get rid of the letters associated with the amount of memory
df
# Out:
#       Unnamed: 0 Company                              Product  \
# 0              1   Apple                          MacBook Pro
# 1              2   Apple                          Macbook Air
# 2              3      HP                               250 G6
# 3              4   Apple                          MacBook Pro
# 4              5   Apple                          MacBook Pro
# ...          ...     ...                                  ...
# 1298        1316  Lenovo                       Yoga 500-14ISK
# 1299        1317  Lenovo                       Yoga 900-13ISK
# 1300        1318  Lenovo                   IdeaPad 100S-14IBR
# 1301        1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302        1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df_companies = df['Company'] #this is to list out all the dataframes we need to make
df_companies.drop_duplicates()
# Out:
# 0          Apple
# 2             HP
# 5           Acer
# 8           Asus
# 13          Dell
# 18        Lenovo
# 30         Chuwi
# 58           MSI
# 70     Microsoft
# 143      Toshiba
# 170       Huawei
# 184       Xiaomi
# 191         Vero
# 196        Razer
# 429     Mediacom
# 430      Samsung
# 437       Google
# 567      Fujitsu
# 678           LG
# Name: Company, dtype: object

# %%
df_apple = df.loc[df['Company']=='Apple']
df_hp = df.loc[df['Company']=='HP']
df_acer = df.loc[df['Company']=='Acer']
df_asus = df.loc[df['Company']=='Asus']
df_dell = df.loc[df['Company']=='Dell']
df_lenovo = df.loc[df['Company']=='Lenovo']
df_chuwi = df.loc[df['Company']=='Chuwi']
df_msi = df.loc[df['Company']=='MSI']
df_microsoft = df.loc[df['Company']=='Microsoft']
df_toshiba = df.loc[df['Company']=='Toshiba']
df_huawei = df.loc[df['Company']=='Huawei']
df_xiaomi = df.loc[df['Company']=='Xiaomi']
df_vero = df.loc[df['Company']=='Vero']
df_razer = df.loc[df['Company']=='Razer']
df_mediacom = df.loc[df['Company']=='Mediacom']
df_samsung = df.loc[df['Company']=='Samsung']
df_google = df.loc[df['Company']=='Google']
df_fujitsu = df.loc[df['Company']=='Fujitsu']
df_lg = df.loc[df['Company']=='LG']

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=df, y=df['Price_euros'], x=df['Ram'], hue=df['Company'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=df, y=df['Price_euros'], x=df['Memory'], hue=df['Company'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=df, y=df['Price_euros'], x=df['Inches'], hue=df['Company'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.scatter(y=df_apple['Price_euros'], x=df_apple['Ram'])
plt.title('Apple Laptops')
plt.ylabel('Price (euros)')
plt.xlabel('RAM (in GB)')
plt.show()

# %%
plt.scatter(y=df_hp['Price_euros'], x=df_hp['Ram'])
plt.title('HP Laptops')
plt.ylabel('Price (euros)')
plt.xlabel('RAM (in GB)')
plt.show()

# %%
plt.scatter(y=df_asus['Price_euros'], x=df_asus['Ram'])
plt.title('Asus Laptops')
plt.ylabel('Price (euros)')
plt.xlabel('RAM (in GB)')
plt.show()

# %%
plt.scatter(y=df_lenovo['Price_euros'], x=df_lenovo['Ram'])
plt.title('Lenovo Laptops')
plt.ylabel('Price (euros)')
plt.xlabel('RAM (in GB)')
plt.show()

# %%
x = np.array(df[['Memory', 'Inches', 'Price_euros']])
y = np.array(df['Ram'])
y = y.reshape(-1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=7)

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(x,y)
# Out:
# C:\Users\NHege\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\NHege\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.metrics import accuracy_score
preds = log_reg.predict(x_test)
accuracy_score(y_true=y_test, y_pred=preds)
# Out:
# 0.685823754789272

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_1 = KNeighborsClassifier(n_neighbors = 1)
knn_1.fit(x,y)
knn_5 = KNeighborsClassifier(n_neighbors = 5)
knn_5.fit(x,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
from sklearn.metrics import accuracy_score
preds = knn_1.predict(x_test)
accuracy_score(y_true=y_test, y_pred=preds)
# Out:
# 0.9501915708812261

# %%
from sklearn.metrics import accuracy_score
preds = knn_5.predict(x_test)
accuracy_score(y_true=y_test, y_pred=preds)
# Out:
# 0.789272030651341

# %%
#Change the values in num_1 to be the memory, sceen size, and price you want to use to predict what the ram will be
num_1 = np.array([256,13,2000])
num_1 = num_1.reshape(1, -1)
print(knn_1.predict(num_1))
print(knn_5.predict(num_1))
# Out:
# [16]
# [16]

# %%
#classification accuracy
from sklearn import model_selection
seed = 7
kfold = model_selection.KFold(n_splits=10, random_state=seed)
model = KNeighborsClassifier()
scoring = 'accuracy'
results = model_selection.cross_val_score(model, x, y, cv=kfold, scoring=scoring)
results.mean()
# Out:
# 0.6906635349383441

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
model = KNeighborsClassifier()
model.fit(x_train, y_train)
predicted = model.predict(x_test)
matrix = confusion_matrix(y_test, predicted)
print(matrix)
# Out:
# [[ 3  2  0  0  0  0  0]
#  [ 1 62  0 15  0  0  0]
#  [ 0  3  0  9  0  0  0]
#  [ 0 17  1 95  1  8  0]
#  [ 0  1  0  4  0  0  0]
#  [ 0  0  0 13  0 20  3]
#  [ 0  0  0  0  0  2  1]]

# %%
#classification report
from sklearn.metrics import classification_report
model = LogisticRegression()
model.fit(x_train, y_train)
predicted = model.predict(x_test)
report = classification_report(y_test, predicted)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         5
#            4       0.70      0.72      0.71        78
#            6       0.00      0.00      0.00        12
#            8       0.67      0.87      0.76       122
#           12       0.00      0.00      0.00         5
#           16       0.70      0.44      0.54        36
#           32       0.00      0.00      0.00         3
#
#     accuracy                           0.68       261
#    macro avg       0.30      0.29      0.29       261
# weighted avg       0.62      0.68      0.64       261
# C:\Users\NHege\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...
